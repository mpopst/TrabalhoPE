# %%
from exercicio6 import exercicio6
import numpy as np

# %%
exercicio6(10)
# Out:
# (array([-0.19008474, -0.36785522, -1.10554206, -0.56756154, -0.73244139,
#         -0.47411875, -0.8020471 , -0.49324794,  0.12443546, -0.25547426]),
#  0.12443545849578558)

# %%
np.concatenate([np.array([0]), np.array([1,23])], axis=0)
# Out:
# array([ 0,  1, 23])
